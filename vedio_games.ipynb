# %% [markdown]
# The dataset is a video game sales dataset with 16,598 rows and 11 columns. Here is an overview of its structure:
#
# Columns:
# * Rank: Integer, the ranking of the game based on global sales.
# * Name: Object, the name of the video game.
# * Platform: Object, the gaming platform (e.g., Wii, NES, PS).
# * Year: Float64, the year of release.
# * Genre: Object, the game's genre (e.g., Sports, Platform, Racing).
# * Publisher: Object, the company that published the game.
# * NA_Sales: Float64, sales in North America (in millions of units).
# * EU_Sales: Float64, sales in Europe (in millions of units).
# * JP_Sales: Float64, sales in Japan (in millions of units).
# * Other_Sales: Float64, sales in other regions (in millions of units).
# * Global_Sales: Float64, total global sales (in millions of units).
#
#
# * Dataset Details:
# * Shape: 16,598 rows × 11 columns
# * Data Types: A mix of numerical (integer, float) and categorical (object) columns.
#
# # target variable:
#    * global sales

# %% [raw]
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
# Rank - Ranking of overall sales
#
# Name - The games name
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
# Year - Year of the game's release
#
# Genre - Genre of the game
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales.
#
# The script to scrape the data is available at https://github.com/GregorUT/vgchartzScrape.
# It is based on BeautifulSoup using Python.
# There are 16,598 records. 2 records were dropped due to incomplete information.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df=pd.read_csv('/content/vgsales (1).csv')

# %%
df
# Out:
#         Rank   Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0          1  10849        26  2006.0     10        359     41.49     29.02
# 1          2   9201        11  1985.0      4        359     29.08      3.58
# 2          3   5493        26  2008.0      6        359     15.85     12.88
# 3          4  10851        26  2009.0     10        359     15.75     11.01
# 4          5   7247         5  1996.0      7        359     11.27      8.89
# ...      ...    ...       ...     ...    ...        ...       ...       ...
# 16286  16596  10942         6  2002.0      4        269      0.01      0.00
# 16287  16597   5713         7  2003.0      8        241      0.01      0.00
# 16288  16598   8039        16  2008.0      6         21      0.00      0.00
# 16289  16599   4938         4  2010.0      5          8      0.00      0.01
# 16290  16600   8850         6  2003.0      4        544      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
#checking null values
df.isnull().sum()

#droping null values
df=df.dropna()
df.reset_index(drop=True, inplace=True)
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
#checking duplicates
df[df.duplicated()] #there is no duplicates
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16286  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16287  16597                     Men in Black II: Alien Escape       GC
# 16288  16598  SCORE International Baja 1000: The Official Game      PS2
# 16289  16599                                        Know How 2       DS
# 16290  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#descriptive statistics
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
df['Name'].unique()
df['Platform'].unique()
df['Genre'].unique()
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
#ploting the histogram to understand the skew on the data

import matplotlib.pyplot as plt
import seaborn as sn
df.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'NA_Sales'}>],
#        [<Axes: title={'center': 'EU_Sales'}>,
#         <Axes: title={'center': 'JP_Sales'}>,
#         <Axes: title={'center': 'Other_Sales'}>],
#        [<Axes: title={'center': 'Global_Sales'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
#feature engineiring
#converting all qualitative elements into quantitative using label encoder

x=['Name','Platform','Genre','Publisher']
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in x:
    df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  int64
#  2   Platform      16291 non-null  int64
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  int64
#  5   Publisher     16291 non-null  int64
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(5)
# memory usage: 1.4 MB

# %%
x=df.corr()
import seaborn as sn
plt.figure(figsize=(12, 8))
sn.heatmap(x,annot=True,robust=True,cmap='Greens')
# Out:
# <Axes: >

# %%
#plot boxplot to detect out layers

plt.figure(figsize=(12, 8))
plt.boxplot(df,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d1c9c626830>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d1c9c6255d0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7d1c9c624be0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7d1c550588b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7d1c55059de0>,
# ...
#  'means': []}

# %%
# # REMOVING OUT LAYRES
# import numpy as np
# x=['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales']
# for i in x:
#     data=df[i]
#     q1=np.quantile(data,0.25)
#     q2=np.quantile(data,0.50)
#     q3=np.quantile(data,0.75)
#     iqr=q3-q1
#     lower=q1-(1.5*iqr)
#     upper=q3+(1.5*iqr)
#     outliers=[j for j in data if j<lower or j>upper]
#     print(len(outliers))
#     df1= df[(df[i] >= lower) & (df[i] <= upper)]

# %%
df
# Out:
#         Rank   Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0          1  10849        26  2006.0     10        359     41.49     29.02
# 1          2   9201        11  1985.0      4        359     29.08      3.58
# 2          3   5493        26  2008.0      6        359     15.85     12.88
# 3          4  10851        26  2009.0     10        359     15.75     11.01
# 4          5   7247         5  1996.0      7        359     11.27      8.89
# ...      ...    ...       ...     ...    ...        ...       ...       ...
# 16286  16596  10942         6  2002.0      4        269      0.01      0.00
# 16287  16597   5713         7  2003.0      8        241      0.01      0.00
# 16288  16598   8039        16  2008.0      6         21      0.00      0.00
# 16289  16599   4938         4  2010.0      5          8      0.00      0.01
# 16290  16600   8850         6  2003.0      4        544      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  int64
#  2   Platform      16291 non-null  int64
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  int64
#  5   Publisher     16291 non-null  int64
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(5)
# memory usage: 1.4 MB

# %%
from sklearn.model_selection import train_test_split
x=df.drop(columns='Global_Sales')
y=df['Global_Sales']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,shuffle=True)

# %%
#importing model to evaluate
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#predicting the data using x_test
model.fit(x_train,y_train)
prediction=model.predict(x_test)

# %%
# finding mae
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,prediction)
mae
# Out:
# 0.003115738520149145

# %%
#calculating mse
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,prediction)
mse
# Out:
# 2.8510041424624615e-05

# %%
#calculating rmse
from math import sqrt
rmse=sqrt(mse)
rmse
# Out:
# 0.005339479508774672

# %%
#calculating the accuracy of the model
from sklearn.metrics import r2_score
accuracy=r2_score(y_test,prediction)
accuracy
# Out:
# 0.9999933356109517
